# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('laptopData.csv')

# %%
df.iloc[20]
# Out:
# Unnamed: 0          NaN
# Company             NaN
# TypeName            NaN
# Inches              NaN
# ScreenResolution    NaN
# Cpu                 NaN
# Ram                 NaN
# Memory              NaN
# Gpu                 NaN
# OpSys               NaN
# Weight              NaN
# Price               NaN
# Name: 20, dtype: object

# %%
df=df.dropna()

# %%
df.iloc[20]
# Out:
# Unnamed: 0                                 21.0
# Company                                  Lenovo
# TypeName                                 Gaming
# Inches                                     15.6
# ScreenResolution    IPS Panel Full HD 1920x1080
# Cpu                 Intel Core i5 7300HQ 2.5GHz
# Ram                                         8GB
# Memory                     128GB SSD +  1TB HDD
# Gpu                     Nvidia GeForce GTX 1050
# OpSys                                Windows 10
# Weight                                    2.5kg
# Price                                  53226.72
# Name: 21, dtype: object

# %%
df= df.reset_index(drop=True)

# %%
df.iloc[43:48]
# Out:
#     Unnamed: 0 Company            TypeName Inches  \
# 43        44.0    Dell  2 in 1 Convertible   17.3
# 44        45.0   Apple           Ultrabook   13.3
# 45        47.0    Asus              Gaming   17.3
# 46        48.0    Dell            Notebook   15.6
# 47        49.0    Asus            Notebook   17.3
#
#                       ScreenResolution                                   Cpu  \
# 43     Full HD / Touchscreen 1920x1080            Intel Core i5 8250U 1.6GHz
# 44  IPS Panel Retina Display 2560x1600                  Intel Core i5 2.0GHz
# 45                   Full HD 1920x1080                   AMD Ryzen 1700 3GHz
# 46                   Full HD 1920x1080            Intel Core i5 7200U 2.5GHz
# 47                            1366x768  Intel Pentium Quad Core N4200 1.1GHz
#
#      Ram                Memory                      Gpu       OpSys  Weight  \
# 43  12GB               1TB HDD     Nvidia GeForce 150MX  Windows 10  2.77kg
# 44   8GB             256GB SSD  Intel Iris Graphics 540       macOS  1.37kg
# 45   8GB  256GB SSD +  1TB HDD        AMD Radeon RX 580  Windows 10   3.2kg
# 46   4GB             256GB SSD       AMD Radeon R5 M430  Windows 10   2.3kg
# 47   4GB               1TB HDD     Nvidia GeForce 920MX  Windows 10   2.8kg
#
#        Price
# 43  53226.72
# 44  75604.32
# 45  69210.72
# 46  34045.92
# 47  24828.48

# %%
df['Unnamed: 0']=range(1,len(df)+1)

# %%
df['Price'] =df['Price'].round(0)

# %%
df.iloc[1]
# Out:
# Unnamed: 0                               2
# Company                              Apple
# TypeName                         Ultrabook
# Inches                                13.3
# ScreenResolution                  1440x900
# Cpu                   Intel Core i5 1.8GHz
# Ram                                    8GB
# Memory                 128GB Flash Storage
# Gpu                 Intel HD Graphics 6000
# OpSys                                macOS
# Weight                              1.34kg
# Price                              47896.0
# Name: 1, dtype: object

# %%
df['Weight']=df['Weight'].str.replace('kg','')

# %%
df.iloc[0]
# Out:
# Unnamed: 0                                           1
# Company                                          Apple
# TypeName                                     Ultrabook
# Inches                                            13.3
# ScreenResolution    IPS Panel Retina Display 2560x1600
# Cpu                               Intel Core i5 2.3GHz
# Ram                                                8GB
# Memory                                       128GB SSD
# Gpu                       Intel Iris Plus Graphics 640
# OpSys                                            macOS
# Weight                                            1.37
# Price                                          71379.0
# Name: 0, dtype: object

# %%
print(df['Weight'].unique())
# Out:
# ['1.37' '1.34' '1.86' '1.83' '2.1' '2.04' '1.3' '1.6' '2.2' '0.92' '1.22'
#  '2.5' '1.62' '1.91' '2.3' '1.35' '1.88' '1.89' '1.65' '2.71' '1.2' '1.44'
#  '2.8' '2' '2.65' '2.77' '3.2' '1.49' '2.4' '2.13' '2.43' '1.7' '1.4'
#  '1.8' '1.9' '3' '1.252' '2.7' '2.02' '1.63' '1.96' '1.21' '2.45' '1.25'
#  '1.5' '2.62' '1.38' '1.58' '1.85' '1.23' '2.16' '2.36' '7.2' '2.05'
#  '1.32' '1.75' '0.97' '2.56' '1.48' '1.74' '1.1' '1.56' '2.03' '1.05'
#  '5.4' '4.4' '1.90' '1.29' '2.0' '1.95' '2.06' '1.12' '3.49' '3.35' '2.23'
#  '?' '2.9' '4.42' '2.69' '2.37' '4.7' '3.6' '2.08' '4.3' '1.68' '1.41'
#  '4.14' '2.18' '2.24' '2.67' '4.1' '2.14' '1.36' '2.25' '2.15' '2.19'
#  '2.54' '3.42' '5.8' '1.28' '2.33' '1.45' '2.79' '8.23' '1.26' '1.84'
#  '0.0002' '2.6' '2.26' '3.25' '1.59' '1.13' '1.42' '1.78' '1.10' '1.15'
#  '1.27' '1.43' '2.31' '1.16' '1.64' '2.17' '1.47' '3.78' '1.79' '0.91'
#  '1.99' '4.33' '1.93' '1.87' '2.63' '3.4' '3.14' '1.94' '1.24' '4.6' '4.5'
#  '8.4' '2.73' '1.39' '2.29' '2.59' '2.94' '11.1' '1.14' '3.8' '6.2' '3.31'
#  '1.09' '3.21' '1.19' '1.98' '1.17' '4.36' '1.71' '2.32' '4.2' '1.55'
#  '0.81' '1.18' '2.72' '1.31' '0.920' '3.74' '1.76' '1.54' '2.83' '2.07'
#  '2.38' '3.58' '1.08' '2.20' '0.98' '2.75' '1.70' '2.99' '1.11' '2.09' '4'
#  '3.0' '0.99' '0.69' '3.52' '2.591' '2.21' '3.3' '2.191' '2.34' '4.0']

# %%
df['Weight'] = df['Weight'].str.replace('?','')

# %%
df['Weight'] = pd.to_numeric(df['Weight'], errors='coerce')

# %%
df=df.dropna(subset=['Weight'])

# %%
df['Weight']=df['Weight'].astype(float)

# %%
df['Weight']=df['Weight'].round(1)

# %%
df.iloc[338]
# Out:
# Unnamed: 0                                 340
# Company                                   Dell
# TypeName                             Ultrabook
# Inches                                    15.6
# ScreenResolution             Full HD 1920x1080
# Cpu                 Intel Core i5 8250U 1.6GHz
# Ram                                        8GB
# Memory                                 1TB HDD
# Gpu                             AMD Radeon 530
# OpSys                               Windows 10
# Weight                                     0.0
# Price                                  35325.0
# Name: 339, dtype: object

# %%
df['Weight'].unique()
# Out:
# array([ 1.4,  1.3,  1.9,  1.8,  2.1,  2. ,  1.6,  2.2,  0.9,  1.2,  2.5,
#         2.3,  2.7,  2.8,  2.6,  3.2,  1.5,  2.4,  1.7,  3. ,  7.2,  1. ,
#         1.1,  5.4,  4.4,  3.5,  3.4,  2.9,  4.7,  3.6,  4.3,  4.1,  5.8,
#         8.2,  0. ,  3.8,  3.1,  4.6,  4.5,  8.4, 11.1,  6.2,  3.3,  4.2,
#         0.8,  3.7,  4. ,  0.7])

# %%
df['Weight'] =df['Weight']*1000

# %%
df['Weight'].unique()
# Out:
# array([ 1400.,  1300.,  1900.,  1800.,  2100.,  2000.,  1600.,  2200.,
#          900.,  1200.,  2500.,  2300.,  2700.,  2800.,  2600.,  3200.,
#         1500.,  2400.,  1700.,  3000.,  7200.,  1000.,  1100.,  5400.,
#         4400.,  3500.,  3400.,  2900.,  4700.,  3600.,  4300.,  4100.,
#         5800.,  8200.,     0.,  3800.,  3100.,  4600.,  4500.,  8400.,
#        11100.,  6200.,  3300.,  4200.,   800.,  3700.,  4000.,   700.])

# %%
df =df[df['Weight'] !=0]

# %%
df['Unnamed: 0']=range(1,len(df)+1)

# %%
print(df.shape)
# Out:
# (1271, 12)

# %%
df.iloc[1260]
# Out:
# Unnamed: 0                                          1261
# Company                                             Dell
# TypeName                                        Notebook
# Inches                                              15.6
# ScreenResolution                                1366x768
# Cpu                 Intel Celeron Dual Core N3050 1.6GHz
# Ram                                                  2GB
# Memory                                         500GB HDD
# Gpu                                    Intel HD Graphics
# OpSys                                         Windows 10
# Weight                                            2200.0
# Price                                            20193.0
# Name: 1262, dtype: object

# %%
df = df.reset_index(drop=True)

# %%
print(df['Inches'].unique())
# Out:
# ['13.3' '15.6' '15.4' '14' '12' '17.3' '13.5' '12.5' '13' '18.4' '13.9'
#  '11.6' '25.6' '35.6' '12.3' '27.3' '24' '33.5' '?' '31.6' '17' '15'
#  '14.1' '11.3' '10.1']

# %%
df = df[pd.to_numeric(df['Inches'], errors='coerce').between(10,20)]

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
print(df['TypeName'].unique())
# Out:
# ['Ultrabook' 'Notebook' 'Gaming' '2 in 1 Convertible' 'Workstation'
#  'Netbook']

# %%
print(df['OpSys'].unique())
# Out:
# ['macOS' 'No OS' 'Windows 10' 'Mac OS X' 'Linux' 'Windows 10 S'
#  'Chrome OS' 'Windows 7' 'Android']

# %%
print(df['Company'].unique())
# Out:
# ['Apple' 'HP' 'Acer' 'Asus' 'Dell' 'Lenovo' 'Chuwi' 'MSI' 'Microsoft'
#  'Toshiba' 'Huawei' 'Xiaomi' 'Vero' 'Razer' 'Mediacom' 'Samsung' 'Google'
#  'Fujitsu' 'LG']

# %%
#df['Memory'] =df['Memory'].str.split('+')

# %%
#df =df.explode('Memory')

# %%
#df['Memory'].unique()

# %%
df['Touch Screen'] = df['ScreenResolution'].str.contains('Touchscreen',na =False).map({True:'Yes',False:'No'})

# %%
df['IPS'] = df['ScreenResolution'].str.contains('IPS',na=False).map({True:'Yes',False:'No'})

# %%
df['Retina'] = df['ScreenResolution'].str.contains('Retina',na=False).map({True:'Yes',False:'No'})

# %%
df[['Width','Height']] = df['ScreenResolution'].str.extract(r'(\d+)x(\d+)').astype(float)

# %%
#df['Maximum Display Resolution'] = df['ScreenResolution'].str.extract(r'(Full HD|Quad HD\+?|4K Ultra HD)')

# %%
res_map = {
    (1366.0, 768.0): 'HD / HD+',
    (1440.0, 900.0): 'HD / HD+',
    (1600.0, 900.0): 'HD / HD+',
    (1920.0, 1080.0): 'Full HD (FHD)',
    (1920.0, 1200.0): 'Full HD (FHD)',
    (2560.0, 1440.0): 'Quad HD (QHD)',
    (2256.0, 1504.0): 'Quad HD+ (QHD+)',
    (2304.0, 1440.0): 'Quad HD+ (QHD+)',
    (2560.0, 1600.0): 'Quad HD+ (QHD+)',
    (2736.0, 1824.0): 'Quad HD+ (QHD+)',
    (2880.0, 1800.0): 'Quad HD+ (QHD+)',
    (3200.0, 1800.0): 'Quad HD+ (QHD+)',
    (2400.0, 1600.0): 'Quad HD+ (QHD+)',
    (3840.0, 2160.0): '4K Ultra HD (UHD)'
}

# %%
df['Maximum Display Resolution'] = pd.Series(list(zip(df['Width'], df['Height'],))).map(res_map)

# %%
df['Maximum Display Resolution'] =df['Maximum Display Resolution'].fillna('Not Available')

# %%
print(df['Maximum Display Resolution'].unique())
# Out:
# ['Quad HD+ (QHD+)' 'HD / HD+' 'Full HD (FHD)' '4K Ultra HD (UHD)'
#  'Not Available' 'Quad HD (QHD)']

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName Inches                    ScreenResolution  \
# 0           1   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1           2   Apple  Ultrabook   13.3                            1440x900
# 2           3      HP   Notebook   15.6                   Full HD 1920x1080
# 3           4   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4           5   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight     Price Touch Screen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS  1400.0   71379.0           No  Yes
# 1        Intel HD Graphics 6000  macOS  1300.0   47896.0           No   No
# 2         Intel HD Graphics 620  No OS  1900.0   30636.0           No   No
# 3            AMD Radeon Pro 455  macOS  1800.0  135195.0           No  Yes
# 4  Intel Iris Plus Graphics 650  macOS  1400.0   96096.0           No  Yes
#
#   Retina   Width  Height Maximum Display Resolution
# 0    Yes  2560.0  1600.0            Quad HD+ (QHD+)
# 1     No  1440.0   900.0                   HD / HD+
# 2     No  1920.0  1080.0              Full HD (FHD)
# 3    Yes  2880.0  1800.0            Quad HD+ (QHD+)
# 4    Yes  2560.0  1600.0            Quad HD+ (QHD+)

# %%
def splitting(col name):
     numbers - reg ex
     features - Full HD / Quad HD+ / 4K Ultra HD: yes assign no nan
     panel - ips or retina
     touch screen  or not
     resolution  has width and height
     change  nan to not available
